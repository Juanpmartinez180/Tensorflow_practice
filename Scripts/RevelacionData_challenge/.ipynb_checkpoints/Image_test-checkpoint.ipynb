# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
session = tf.Session()
# %config Completer.use_jedi = False
import PIL
import PIL.Image

ops.reset_default_graph()
session = tf.Session()

# %%
data_image = 'Honda/Biz/4xre300.jpg'
image = tf.keras.preprocessing.image.load_img(data_image, grayscale= True, color_mode= 'rgb', target_size=None, interpolation= 'nearest')

input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
import pathlib
data_dir = pathlib.Path('Honda/')
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)  #Numer of images in dir
# Out:
# 115

# %% [markdown]
# Opening a picture from directory

# %%
tornado = list(data_dir.glob('Tornado/*'))
PIL.Image.open(str(tornado[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x160 at 0x7F0C8C6CA290>

# %%
tornado
# Out:
# [PosixPath('Honda/Tornado/2018xr250tornadod06-160x160.jpg'),
#  PosixPath('Honda/Tornado/011a0e759d98e170b76c07b442b88fa3.jpg'),
#  PosixPath('Honda/Tornado/2cfa1119c59ea99e1c1bd468678e8ba9.jpg'),
#  PosixPath('Honda/Tornado/049dc852-1615639539-619.jpg'),
#  PosixPath('Honda/Tornado/442603_1_im.jpg'),
#  PosixPath('Honda/Tornado/2019xr250rojo-1.jpg'),
#  PosixPath('Honda/Tornado/60219.jpg'),
#  PosixPath('Honda/Tornado/5d03f1a846ecf4603bd420b3633c3731.jpg'),
#  PosixPath('Honda/Tornado/117_0s-0web-tornado-motor.jpg'),
#  PosixPath('Honda/Tornado/350abc26-1613907390-89.jpg'),
#  PosixPath('Honda/Tornado/05720motor-XR250.jpg'),
#  PosixPath('Honda/Tornado/252_1.jpg'),
#  PosixPath('Honda/Tornado/159608_img_20210306_173010.jpg.thb.jpg'),
#  PosixPath('Honda/Tornado/65563_10203797616713533_5910893249814620225_n.jpg'),
#  PosixPath('Honda/Tornado/1081c8d8-1611492704-813.jpg'),
#  PosixPath('Honda/Tornado/409doqfwop6sbtqda6wulgj5y.jpg'),
# ...

# %%
batch_size = 32 
img_height = 180
img_width = 180

# %%
data_image = 'Honda/Tornado/2018xr250tornadod06-160x160.jpg'
image = tf.keras.preprocessing.image.load_img(data_image, grayscale= True, color_mode= 'rgb', target_size=None, interpolation= 'nearest')

input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
tf.image.resize_image_with_crop_or_pad(input_arr, 28,28)

#crop aleatorio
final_image = tf.image.resize_image_with_crop_or_pad(input_arr, 28,28)
if True:
    #flip aleatorio horizontal, cambiar brillo y contraste
    final_image = tf.image.random_flip_left_right(final_image)
    final_image = tf.image.random_brightness(final_image, max_delta=63)
    final_image = tf.image.random_contrast(final_image, lower=0.2, upper=1.8)
#estandarización por color
final_image = tf.image.per_image_standardization(final_image)
